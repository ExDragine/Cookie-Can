# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Data_Raw = pd.read_excel('data.xlsx')
Year,Power_Add,Sell_Add,GDP_Add,Power,Election=['年份','|能源消费比上年增长/%','电力消费比上年增长/%','国内生产总值比上年增长/%','能源消费弹性系数','电力消费弹性系数']
Year = np.array(Data.年份,dtype='int64')
Power = np.array(Data.能源消费弹性系数,dtype='float64')
Election = np.array(Data.电力消费弹性系数,dtype='float64')

# %%
fig, axs = plt.subplots(3, 1)
axs[0].plot(Year, Power, Year, Election)
# axs[0].set_xlim(0, 2)
axs[0].set_xlabel('Year')
axs[0].set_ylabel('Power and Election')
axs[0].grid(True)
axs[0].legend('best')

axs[1].plot(Year,Power)
axs[1].set_ylabel('Power')

axs[2].plot(Year,Election)
axs[2].set_ylabel('Election')

fig.tight_layout()
plt.show()
